# %%
from glob import glob
import pandas as pd
from sys import exit

path = r'C:/users/mueller/desktop/rwth phd/narayanan_xrd/vergleich'

dat_files = (glob(f'{path}/SCALMS*'))
dat_dfs = [pd.read_csv(dat_file, sep='\s+', names=['r', 'I'], header=None, skiprows=27) for dat_file in dat_files]
name = [file.split('\\')[-1] for file in dat_files]
name
# Out:
# ['SCALMS_1_M3.gr',
#  'SCALMS_1_nochmal.gr',
#  'SCALMS_2_M3.gr',
#  'SCALMS_2_sum_817_831.gr',
#  'SCALMS_3_M3.gr',
#  'SCALMS_3_sum_832_846.gr',
#  'SCALMS_4_M3.gr',
#  'SCALMS_4_sum_847_861.gr',
#  'SCALMS_5_M3.gr',
#  'SCALMS_5_sum_862_876.gr',
#  'SCALMS_6_M3.gr',
#  'SCALMS_6_sum_877_891.gr',
#  'SCALMS_7_M3.gr',
#  'SCALMS_7_sum_892_906.gr',
#  'SCALMS_8_M3.gr',
#  'SCALMS_8_sum_907_921.gr',
#  'SCALMS_9_M3.gr',
#  'SCALMS_9_sum_922_936.gr',
#  'SCALMS_SiO2_sum_787_801.gr']

# %%
for i, j in enumerate(['a', 'b', 'c']):
    print(f'{i=}{j=}')
# Out:
# i=0j='a'
# i=1j='b'
# i=2j='c'

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from itertools import cycle
color = cm.rainbow(np.linspace(0, 1, 4))



zuordnung = [2, 4, 4, 4, 4]

font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
pos = 0
fig, axes = plt.subplots(5, 1, figsize=(16,39), sharex=True, sharey=True)
for ax, zo in zip(axes.flat, zuordnung):
    
    for j, co in zip(range(zo), color):
        ax.plot(dat_dfs[pos+j].r, dat_dfs[pos+j].I, '-', label=name[pos + j ], c=co)
    pos += zo
    print(pos)
    
    ax.set_ylabel('G(r) / a.u.', fontdict=font)
    ax.legend(loc=1)
    ax.legend(loc=1)

ax.set_xlim(0, 30)
ax.set_xlim(0, 30)
ax.set_xlabel('r / Å', fontdict=font)




plt.tight_layout()
plt.show
# Out:
# 2
# 6
# 10
# 14
# 18
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(16,39))

ax1.plot(dat_dfs[0].r, dat_dfs[0].I, 'r-', label=name[0])
ax1.plot(dat_dfs[1].r, dat_dfs[1].I, 'b-', label=name[1])

ax2.plot(dat_dfs[2].r, dat_dfs[2].I, 'r-', label=name[2])
ax2.plot(dat_dfs[3].r, dat_dfs[3].I, 'b-', label=name[3])
ax2.plot(dat_dfs[4].r, dat_dfs[4].I, 'g-', label=name[4])
ax2.plot(dat_dfs[5].r, dat_dfs[5].I, 'c-', label=name[5])

(ax1, ax2, ax3, ax4, ax5)


ax1.set_xlim(0, 30)
ax2.set_xlim(0, 30)
plt.xlabel('r / Å', fontdict=font)
plt.ylabel('G(r) / a.u.', fontdict=font)
ax1.legend(loc=1)
ax2.legend(loc=1)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
